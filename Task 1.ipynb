# %%
import pandas as pd
import math

# %%
sad_df = pd.read_csv("./salary_and_population.csv")

# %%
sad_df.head(40)
# Out:
#                           Region_RU                     Region_EN  AVG_Salary  \
# 0                    Алтайский край                  Altai Region       25960
# 1                  Амурская область                   Amur Region       43156
# 2             Архангельская область            Arkhangelsk Region       47526
# 3              Астраханская область              Astrakhan Region       32166
# 4              Белгородская область               Belgorod Region       31163
# 5                  Брянская область                Bryansk Region       27403
# 6              Владимирская область               Vladimir Region       31647
# 7             Волгоградская область              Volgograd Region       30097
# 8               Вологодская область                Vologda Region       36081
# 9               Воронежская область               Voronezh Region       31286
# 10                         г Москва                        Moscow       78946
# ...

# %%
index_names = sad_df[(sad_df['Region_EN'] == 'Orel') | (sad_df['Region_EN'] == 'Nizhny Novgorod Region') | (sad_df['Region_EN'] == 'Novosibirsk Region')].index

# %%
sad_df.drop(index_names, inplace=True)

# %%
sad_df.to_csv('sad_changed.csv')

# %% [markdown]
# ## Выборочное среднее

# %%
round(sad_df.AVG_Salary.mean(), 2)
# Out:
# 39083.51

# %% [markdown]
# ## Выборочная медиана

# %%
round(sad_df.AVG_Salary.median(), 2)
# Out:
# 32779.5

# %% [markdown]
# ## Дисперсия (Variance)

# %%
round(sad_df.AVG_Salary.var(), 2)
# Out:
# 278595953.86

# %% [markdown]
# ## Среднеквадратическое отклонение (Standart diviation)

# %%
round(sad_df.AVG_Salary.std(), 2)
# Out:
# 16691.19
